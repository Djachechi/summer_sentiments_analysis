# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
load_dotenv()
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\sdjac\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
api_key = os.getenv("news_api")
len(api_key)
# Out:
# 32

# %%
# Create a newsapi client
from newsapi import NewsApiClient
Database = NewsApiClient(api_key=api_key)

# %%
# Fetch the Heat news articles
Heat_headlines = Database.get_everything(
    q="Heat",
    language="en",
    page_size=50, 
    sort_by="relevancy" 
)

# %%
# Fetch the Refreshing news articles
Refreshing_headlines = Database.get_everything(
    q="Refreshing",
    language="en",
    page_size=50, 
    sort_by="relevancy" 
)

# %%
# Create the Heat sentiment scores DataFrame
Heat_sentiments = []

for article in Heat_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        Heat_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
        


# Create DataFrame
Heat_df = pd.DataFrame(Heat_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
Heat_df = Heat_df[cols]

Heat_df.head()
# Out:
#                    date                                               text  \
# 0  2022-05-25T20:00:00Z  With temperatures rising in many places, lawn ...
# 1  2022-05-19T22:36:23Z  Under these conditions, she said, fires are re...
# 2  2022-05-28T09:00:41Z  We dont own cars, so we cant drive to lakes an...
# 3  2022-05-13T23:46:35Z  Democrats have giddily circulated their own re...
# 4  2022-05-23T05:46:33Z  Image caption, The rain led to traffic jams an...
#
#    compound  positive  negative  neutral
# 0    0.0772     0.078     0.095    0.827
# 1   -0.1027     0.068     0.103    0.829
# 2    0.0000     0.000     0.000    1.000
# 3    0.0000     0.000     0.000    1.000
# 4   -0.2732     0.000     0.060    0.940

# %%
# Create the Refreshing sentiment scores DataFrame
Refreshing_sentiments = []

for article in Refreshing_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        Refreshing_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
        


# Create DataFrame
Refreshing_df = pd.DataFrame(Refreshing_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
Refreshing_df = Refreshing_df[cols]

Refreshing_df.head()
# Out:
#                    date                                               text  \
# 0  2022-05-27T16:00:16Z  Young golfers can now turn their physical surr...
# 1  2022-06-07T20:19:17Z  Enlarge/ I'm pretty sure that's the Predator i...
# 2  2022-05-13T15:00:07Z  I think we can all agree that having any degre...
# 3  2022-06-10T20:00:11Z  Some swear it tastes just like Coca-Cola, othe...
# 4  2022-05-23T14:00:00Z  The Odyssey Neo G8 in action. | Image: Samsung...
#
#    compound  positive  negative  neutral
# 0    0.3612     0.072     0.000    0.928
# 1    0.8225     0.262     0.061    0.678
# 2    0.6369     0.129     0.000    0.871
# 3   -0.4215     0.120     0.191    0.689
# 4    0.0000     0.000     0.000    1.000

# %%
# Describe the Heat Sentiment
Heat_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  50.000000  50.000000  50.000000  50.000000
# mean    0.069540   0.069160   0.054680   0.876140
# std     0.402807   0.073061   0.047832   0.087683
# min    -0.739100   0.000000   0.000000   0.681000
# 25%    -0.190000   0.000000   0.000000   0.813000
# 50%     0.000000   0.059000   0.062000   0.882500
# 75%     0.382850   0.133250   0.087500   0.935000
# max     0.865800   0.243000   0.185000   1.000000

# %%
# Describe the Ethereum Sentiment
Refreshing_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  50.000000  50.000000  50.000000  50.000000
# mean    0.298802   0.107460   0.037840   0.854720
# std     0.452626   0.090236   0.053343   0.104171
# min    -0.726900   0.000000   0.000000   0.611000
# 25%     0.000000   0.039250   0.000000   0.780250
# 50%     0.350600   0.088500   0.000000   0.874000
# 75%     0.750600   0.195500   0.060500   0.935000
# max     0.891200   0.286000   0.191000   1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Ethereum
#
# Q: Which coin had the highest compound score?
#
# A: Ethereum
#
# Q. Which coin had the highest positive score?
#
# A: Ethereum

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# Create a list of SWwords
import nltk
nltk.download('stopwords')
stop_words = stopwords.words('english')


# Expand the default SWwords list if necessary
list(stop_words)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sdjac\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Remove the punctuation from text
#words = list(filter(lambda t: t not in punctuation, words))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text)

    # Create a tokenized list of the words
    words = word_tokenize(re_clean)
    
    # Lemmatize words into root words
    lemmatizer = WordNetLemmatizer()
    lem = [lemmatizer.lemmatize(word) for word in words]
    
    # Remove the stop words
    # Convert the words to lowercase
    tokens = [word.lower() for word in lem if word.lower() not in stop_words]
        
    
    return tokens

# %%
# Create a new tokens column for Heat
Heat_df['tokens']=[tokenizer(word) for word in Heat_df['text']]
Heat_df.head()
# Out:
#                    date                                               text  \
# 0  2022-05-25T20:00:00Z  With temperatures rising in many places, lawn ...
# 1  2022-05-19T22:36:23Z  Under these conditions, she said, fires are re...
# 2  2022-05-28T09:00:41Z  We dont own cars, so we cant drive to lakes an...
# 3  2022-05-13T23:46:35Z  Democrats have giddily circulated their own re...
# 4  2022-05-23T05:46:33Z  Image caption, The rain led to traffic jams an...
#
#    compound  positive  negative  neutral  \
# 0    0.0772     0.078     0.095    0.827
# 1   -0.1027     0.068     0.103    0.829
# 2    0.0000     0.000     0.000    1.000
# 3    0.0000     0.000     0.000    1.000
# 4   -0.2732     0.000     0.060    0.940
#
#                                               tokens
# 0  [temperature, rising, many, place, lawn, care,...
# 1  [condition, said, fire, really, easily, starte...
# 2  [dont, car, cant, drive, lake, beach, stuff, j...
# 3  [democrats, giddily, circulated, research, ind...
# 4  [image, caption, rain, led, traffic, jam, flig...

# %%
# Create a new tokens column for Refreshing
Refreshing_df['tokens']=[tokenizer(word) for word in Refreshing_df['text']]
Refreshing_df.head()
# Out:
#                    date                                               text  \
# 0  2022-05-27T16:00:16Z  Young golfers can now turn their physical surr...
# 1  2022-06-07T20:19:17Z  Enlarge/ I'm pretty sure that's the Predator i...
# 2  2022-05-13T15:00:07Z  I think we can all agree that having any degre...
# 3  2022-06-10T20:00:11Z  Some swear it tastes just like Coca-Cola, othe...
# 4  2022-05-23T14:00:00Z  The Odyssey Neo G8 in action. | Image: Samsung...
#
#    compound  positive  negative  neutral  \
# 0    0.3612     0.072     0.000    0.928
# 1    0.8225     0.262     0.061    0.678
# 2    0.6369     0.129     0.000    0.871
# 3   -0.4215     0.120     0.191    0.689
# 4    0.0000     0.000     0.000    1.000
#
#                                               tokens
# 0  [young, golfer, turn, physical, surroundings, ...
# 1  [enlarge, im, pretty, sure, thats, predator, m...
# 2  [think, agree, degree, outdoor, space, treat, ...
# 3  [swear, taste, like, cocacola, others, gag, di...
# 4  [odyssey, neo, g, action, image, samsung, sams...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Heat N-grams where N=2
Heat_ngram = []
for token in Heat_df['tokens']:
    for text in token:
        Heat_ngram.append(text)
Heat_bigram_counts = Counter(ngrams(Heat_ngram, n=2))
Heat_bigram_counts.most_common(10)
# Out:
# [(('boston', 'celtics'), 8),
#  (('may', 'reuters'), 8),
#  (('miami', 'heat'), 7),
#  (('jimmy', 'butler'), 4),
#  (('char', 'may'), 4),
#  (('eastern', 'conference'), 3),
#  (('char', 'boston'), 3),
#  (('char', 'miami'), 3),
#  (('june', 'reuters'), 3),
#  (('browser', 'isnt'), 3)]

# %%
# Generate the Refreshing N-grams where N=2
Refreshing_ngram = []
for token in Refreshing_df['tokens']:
    for text in token:
        Refreshing_ngram.append(text)
Refreshing_bigram_counts = Counter(ngrams(Refreshing_ngram, n=2))
Refreshing_bigram_counts.most_common(10)
# Out:
# [(('char', 'may'), 3),
#  (('ms', 'marvel'), 3),
#  (('iga', 'swiatek'), 3),
#  (('odyssey', 'neo'), 2),
#  (('neo', 'g'), 2),
#  (('char', 'refreshing'), 2),
#  (('iman', 'vellani'), 2),
#  (('vellani', 'kamala'), 2),
#  (('kamala', 'khan'), 2),
#  (('many', 'people'), 2)]

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
token_count(Heat_ngram, 10)
# Out:
# [('char', 45),
#  ('heat', 27),
#  ('boston', 11),
#  ('reuters', 11),
#  ('celtics', 10),
#  ('may', 10),
#  ('miami', 9),
#  ('temperature', 8),
#  ('ha', 7),
#  ('wa', 7)]

# %%
# Use token_count to get the top 10 words for Refreshing
token_count(Refreshing_ngram, 10)
# Out:
# [('char', 50),
#  ('new', 11),
#  ('refreshing', 11),
#  ('ha', 6),
#  ('may', 6),
#  ('today', 5),
#  ('time', 5),
#  ('one', 5),
#  ('wa', 5),
#  ('first', 5)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
def wordcloud(text, title=""):
    df_cloud = WordCloud(width=500, colormap='RdYlBu').generate(text)
    plt.imshow(df_cloud)
    plt.axis("off")
    fontdict = {"fontsize": 48, "fontweight" : "bold"}
    plt.title(title, fontdict=fontdict)
    plt.show()

# %%
# Generate the Heat word cloud
wordcloud(Heat_df.text.str.cat(), title="Heat Word Cloud")

# %%
# Generate the Refreshing word cloud
wordcloud(Refreshing_df.text.str.cat(), title="Refreshing Word Cloud")

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Heat NER

# %%
def listToString(s):    
    # initialize an empty string 
    str1 = " " 
    # return string   
    return (str1.join(s))

# %%
# Concatenate all of the Heat text together
Heat_big_string = listToString(Heat_df['text'])

# %%
# Run the NER processor on all of the text
Heat_doc = nlp(Heat_big_string)

# Add a title to the document
Heat_doc.user_data['title'] = 'Heat NER'

# %%
# Render the visualization
displacy.render(Heat_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Heat NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">With temperatures rising in many places, lawn care season has officially begun and the struggle to keep the grass from turning brown through the heat of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     summer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>The fire in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Taylor County
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  was the product of a roadside start, Ms.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Roberts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said. The origin could have
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# … [
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     +843
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  chars] We dont own cars, so we cant drive to lakes and beaches and stuff,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jesse Amaro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , a home health aide, said outside the Crotona Pool in the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bronx
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . It was on
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of last summers hottest days, and the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# … [+1534 chars]
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Democrats
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  have giddily circulated their own research indicating that Barnette is leading the field in the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Senate
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  race by
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about 10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  percentage points, but that survey was conducted before
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>A thunderstorm in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 's
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     capital city
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Delhi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , led to a steep drop in temperature and caused power blackouts in several areas on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>Jayson Tatum rediscovered top form to help the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Boston Celtics
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  level their Eastern Conference play-off final with the M… [+1052 chars]
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jimmy Butler
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , who has been in the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NBA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  All-Star team
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     six
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  times, joined
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Miami Heat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="e

# %%
# List all Entities
for ent in Heat_doc.ents:
    print(ent.text, ent.label_)
# Out:
# summer DATE
# Taylor County GPE
# Roberts PERSON
# bee ORG
# +843 PERSON
# Jesse Amaro PERSON
# Bronx GPE
# one CARDINAL
# lin PERSON
# Democrats NORP
# Senate ORG
# about 10 CARDINAL
# Trump ORG
# India GPE
# capital city GPE
# Delhi GPE
# Monday DATE
# Boston Celtics ORG
# Jimmy Butler PERSON
# NBA ORG
# six CARDINAL
# Miami Heat FAC
# 2019 DATE
# Jimmy Butler PERSON
# 47 CARDINAL
# Miami Heat ORG
# Boston Celtics ORG
# 111 CARDINAL
# Boston GPE
# Jayson Tatum PERSON
# MVP ORG
# The Boston Celtics ORG
# NBA ORG
# first ORDINAL
# 12 years DATE
# Miami Heat ORG
# 100 CARDINAL
# Bos PERSON
# Marcus Smart ORG
# five CARDINAL
# three CARDINAL
# the Heat
# Marcus Smart ORG
# Boston Celtics ORG
# the Miami Heat LOC
# millions CARDINAL
# 50C CARDINAL
# MIT ORG
# lightto GPE
# Bam Adebayo PERSON
# Jimmy Butler PERSON
# the second half DATE
# Bam Adebayo PERSON
# 31 CARDINAL
# Miami Heat GPE
# the Boston Celtics 109 ORG
# Northeast LOC
# late-season DATE
# the Rocky Mountains LOC
# The Greater Toronto Area WORK_OF_ART
# first ORDINAL
# this year DATE
# Canada GPE
# hundreds CARDINAL
# British Columbia GPE
# Lisa Lapointe PERSON
# Muhammad Akbar PERSON
# 40 DATE
# Jacobabad LOC
# three CARDINAL
# those days DATE
# LONDON GPE
# May 18 DATE
# Reuters ORG
# The Fine Print WORK_OF_ART
# PHILADELPHIA GPE
# AP ORG
# Jimmy Butler PERSON
# Joel Embiid PERSON
# 76ers CARDINAL
# MIAMI GPE
# AP ORG
# the NBA Finals three LAW
# the previous five seasons DATE
# the Boston Celtics ORG
# East LOC
# The Miami Heat ORG
# second ORDINAL
# three years DATE
# 99-90 CARDINAL
# Game 6 EVENT
# Thursday DATE
# night TIME
# the Wells Fargo Center ORG
# Mia PERSON
# BOSTON GPE
# 102 CARDINAL
# three CARDINAL
# Jimmy the Greek PERSON
# summer DATE
# June 8 DATE
# Reuters ORG
# Germanys GPE
# Thermondo PERSON
# May 22 DATE
# Reuters ORG
# Lando Norris ORG
# eighth ORDINAL
# the Spanish ORG
# all week DATE
# June 1 DATE
# Reuters ORG
# Greek NORP
# the summer season DATE
# SEVILLE ORG
# May 18 DATE
# Reuters ORG
# Eintracht Frankfurt ORG
# Rangers ORG
# Wednesday DATE
# Europa League ORG
# May 26 DATE
# 24 minutes TIME
# Boston Celtics ORG
# Wednesday DATE
# one CARDINAL
# first ORDINAL
# American NORP
# the weekend DATE
# US GPE
# Phoenix GPE
# Las GPE
# Spain GPE
# Italy GPE
# Africa LOC
# this week DATE
# Anticyclone Scipio ORG
# Africa LOC
# Mediterranean LOC
# Spain GPE
# 42C CARDINAL
# Saturday DATE
# 26 CARDINAL
# the Boston Celtics ORG
# Saturday DATE
# night TIME
# 109 CARDINAL
# TD Garden FAC
# May 20 DATE
# Reuters ORG
# Fed ORG
# minutes TIME
# Boston GPE
# Monday DATE
# night TIME
# Game 3 LAW
# Miami GPE
# NBA ORG
# Envy ORG
# Spectre ORG
# HP ORG
# The HP Pavilion Plu LAW
# Pixel PERSON
# South LOC
# Northeast LOC
# U.S. GPE
# Saturday DATE
# the same day DATE
# prior years DATE
# National Weather Service ORG
# Millions CARDINAL
# US GPE
# a weekend DATE
# YouTube ORG
# Seasonal DATE
# Canadians NORP
# the summer DATE
# YouTube ORG
# YouTube ORG
# the fourth quarter DATE
# HOUSTON GPE
# May 13 DATE
# Reuters ORG
# Texas GPE
# Friday DATE
# this weekend DATE
# six CARDINAL
# May 19 DATE
# Reuters ORG
# the Bank of Japan ORG
# May 21 DATE
# Reuters ORG
# the Preakness Stakes FAC
# Pimlico GPE
# Saturday DATE
# Crown PRODUCT
# Kentucky Derby ORG
# Rich Strike PERSON
# May 18 DATE
# Reuters ORG
# North American NORP
# this summer DATE
# California GPE
# Texas GPE
# U.S. GPE
# Midwest LOC
# June 8 DATE
# Reuters ORG
# the U.S. Southwest ORG
# Wednesday DATE
# 100 degrees QUANTITY

# %% [markdown]
# ---

# %% [markdown]
# ### Refreshing NER

# %%
# Concatenate all of the Refreshing text together
Refreshing_big_string = listToString(Refreshing_df['text'])

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!
Refreshing_doc = nlp(Refreshing_big_string)

# Add a title to the document
Refreshing_doc.user_data['title'] = 'Refreshing NER'

# %%
# Render the visualization
displacy.render(Refreshing_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Refreshing NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Young golfers can now turn their physical surroundings into a digital putting green, courtesy of the same tech behind
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Niantic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's Pokémon Go.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The PGA Jr. League
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  unveiled
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Safari Par-Tee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , a new
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  … [+1256 chars] Enlarge/ I'm pretty sure that's the Predator in the mist, ready to battle in new prequel film
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Prey
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>9 with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>On
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , a wealth of new
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sci-fi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and fantasy trailers emerged fo… [+3575 chars] I think we can all agree that having any degree of outdoor space is a treat and while it typically goes unrecognized and underutilized for most of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the spring
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and summer seasons is its time … [+9875 chars] Some swear it tastes just like
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Coca-Cola
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>The… [+4077 chars] The Odyssey Neo G8 in action. | Image:
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Samsung
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br></br> </br></br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Samsung
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s latest high-end gaming monitor — the curved
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     32-inch
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Odyssey Neo G8
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  — is now available to preorder for $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1,500
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  and will be available to pu… [+1402 chars] As one of the leading makers of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chromebooks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this spring
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  Acer is refreshing its lineup with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  new offerings in the Chromebook Spin 714 and the Chromebook Tab
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     510
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>Starting at $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     750
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  (or $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1,100
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align

# %%
# List all Entities
for ent in Refreshing_doc.ents:
    print(ent.text, ent.label_)
# Out:
# Niantic ORG
# The PGA Jr. League ORG
# today DATE
# Safari Par-Tee PERSON
# AR PRODUCT
# Prey PERSON
# 8 CARDINAL
# Tuesday DATE
# sci-fi ORG
# the year DATE
# the spring DATE
# Coca-Cola ORG
# Samsung ORG
# Samsung ORG
# 32-inch QUANTITY
# Odyssey Neo G8 FAC
# 1,500 MONEY
# Chromebooks ORG
# this spring DATE
# two CARDINAL
# 510 CARDINAL
# 750 MONEY
# 1,100 MONEY
# Italian NORP
# Campari GPE
# juice20 NORP
# Thirsty Suitors PERSON
# HP ORG
# Today DATE
# Envy ORG
# Spectre ORG
# the warmer months ahead DATE
# summer DATE
# Amazon ORG
# Amazon ORG
# Excel PRODUCT
# one CARDINAL
# Microsoft ORG
# Office 365 FAC
# Microsoft ORG
# Iman Vellani PERSON
# Kamala Khan PERSON
# Marvel PERSON
# Iman Vellani PERSON
# Kamala Khan PERSON
# Kamala Khan’s PERSON
# Marvel PERSON
# Marvel PERSON
# 2013 DATE
# May 12 DATE
# Reuters ORG
# Rich Strike PERSON
# next week's DATE
# Preakness Stakes PRODUCT
# Thursday DATE
# the colder months DATE
# Darwin Núñez PERSON
# England GPE
# Monday DATE
# Liverpool ORG
# 100m MONEY
# Benfica PERSON
# Liverpool ORG
# 80 CARDINAL
# today DATE
# Buick‘s GPE
# Ms Marvel ORG
# Disney ORG
# first ORDINAL
# Muslim NORP
# Avengers NORP
# GamesBeat Summit ORG
# 2022 DATE
# One CARDINAL
# PARIS GPE
# June 4 DATE
# Reuters ORG
# first ORDINAL
# French NORP
# 2020 DATE
# one CARDINAL
# second ORDINAL
# Parisian NORP
# Alex Castro PERSON
# The Verge
#
#
#
#
#  Resellers WORK_OF_ART
# More than a year DATE
# PlayStation PRODUCT
# Xbox ORG
# Search Engine Journal ORG
# SEO ORG
# Portugal GPE
# 2021 DATE
# 9.99 MONEY
# 7.99 MONEY
# six CARDINAL
# this weekend DATE
# British NORP
# Lotus ORG
# Asian NORP
# Southall GPE
# London GPE
# The Oculus Quest 2's WORK_OF_ART
# the first two months of 2022 DATE
# Iga Swiatek ORG
# Daria Kasatkina GPE
# three CARDINAL
# three CARDINAL
# 11 CARDINAL
# Zoya MateenBBC News ORG
# Delhi GPE
# Coke Studio ORG
# Pakistan GPE
# Coke Studio Pakistan's ORG
# Pasoori PRODUCT
# India GPE
# nati GPE
# Tan France's PERSON
# Naturally Tan PERSON
# Pakistani NORP
# OnePlus Nord Buds PRODUCT
# Nord ORG
# NEW YORK GPE
# May 19, 2022 DATE
# Today DATE
# OnePlus ORG
# first ORDINAL
# Nord ORG
# the OnePlus Nord LAW
# summer DATE
# late nights DATE
# summer DATE
# Rolling Stone ORG
# Carey PERSON
# ninth ORDINAL
# Patrick Reed PERSON
# Amazon ORG
# 560 CARDINAL
# Cucumber/Green Tea ORG
# 11.47 MONEY
# 2.89 MONEY
# Subscribe &amp ORG
# Save ORG
# American Made ORG
# Tom Cruise PERSON
# Sarah Wright PERSON
# American NORP
# With Top Gun PERSON
# Maverick GPE
# First ORDINAL
# overnight TIME
# Dans NORP
# 28 DATE
# Birmingham GPE
# Latvia GPE
# 2019 DATE
# Georgina GPE
# 31 DATE
# Birmingham GPE
# Occ PERSON
# today DATE
# Sunderland GPE
# A few hours TIME
# Iga Swiatek ORG
# second ORDINAL
# French NORP
# 35th ORDINAL
# Poland GPE
# Alfresco PERSON

# %% [markdown]
# ---
